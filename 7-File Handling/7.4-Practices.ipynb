# %%
with open("notes.txt", "w") as file:
    file.write("Learning Python is fun")

with open("notes.txt","r") as file:
    content=file.read()
    print(content)
# Out:
# Learning Python is fun

# %%
with open("task.txt","w") as file:
    file.write("Hello\n")
    file.write("My name is Shubham Ratan.\n")
    file.write("I am 29 years old.\n")

with open("task.txt","a")as file:
    file.write("Task Completed")


with open("task.txt","r") as file:
    for line in file.readlines():
        print(line)
# Out:
# Hello
#
# My name is Shubham Ratan.
#
# I am 29 years old.
#
# Task Completed

# %%
import os

print(os.getcwd())
# Out:
# d:\mylearning\python\7-File Handling

# %%
os.listdir()
# Out:
# ['7.1-Fileoperations.ipynb',
#  '7.2-Filepath.ipynb',
#  '7.3-CommandLineUtilities.ipynb',
#  '7.4-Practices.ipynb',
#  'destination.txt',
#  'example.bin',
#  'example.txt',
#  'John Doe.txt',
#  'notes.txt',
#  'Package',
#  'ShubhamRatan.txt',
#  'task.txt']

# %%
new_folder="my_folder"
os.mkdir(new_folder)

# %%
import shutil

shutil.copy("task.txt","work.txt")
# Out:
# 'work.txt'

# %%
shutil.move("work.txt","my_folder")
# Out:
# 'my_folder\\work.txt'

# %%
os.remove("task.txt")
