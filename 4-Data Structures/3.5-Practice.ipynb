# %%
marks=[44,56,89,77,95]
mixed=[1,2,3,"Hello",'a',False,3.4]
type(marks)
# Out:
# list

# %%
print(marks)
print(mixed)
# Out:
# [44, 56, 89, 77, 95]
# [1, 2, 3, 'Hello', 'a', False, 3.4]

# %%
print(marks[2])
# Out:
# 89

# %%
print(mixed[5])
# Out:
# False

# %%
marks
# Out:
# [44, 56, 89, 77, 95]

# %%
#marks.pop()
marks.insert(5,5)
print(marks)
# Out:
# [44, 5, 5, 56, 89, 5, 77, 2]

# %%
#Create a list containing table of 5

a=5
table=[]
for i in range(1,11):
    table.append(5*i)

print(table)
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
table=[5*i for i in range (1,11)]
print(table)
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
lst=[i for i in range (1,10) if i%2==0]
print(lst)
# Out:
# [2, 4, 6, 8]

# %%
lst1=[1,2,3]
lst2=[4,5,6]
pair=[[i,j] for i in lst1 for j in lst2]
print(pair)
# Out:
# [[1, 4], [1, 5], [1, 6], [2, 4], [2, 5], [2, 6], [3, 4], [3, 5], [3, 6]]

# %%
fruits=["apple",'banana',"cherry"]
print(fruits[0])
fruits[1]="orange"
print(fruits)
print(len(fruits))
# Out:
# apple
# ['apple', 'orange', 'cherry']
# 3

# %%
lst=[i for i in range(1,11)]
print(lst[0:3])
print(lst[-3:0])
# Out:
# [1, 2, 3]
# []

# %%
lst=[5,2,9,1,7]
lst.sort()
print(lst)
lst.append(10)
print(lst)
lst.remove(2)
print(lst)
# Out:
# [1, 2, 5, 7, 9]
# [1, 2, 5, 7, 9, 10]
# [1, 5, 7, 9, 10]

# %%
lst=["Bob","Alice","Carlie"]
lst.insert(1,"David")
print(lst)
# Out:
# ['Bob', 'David', 'Alice', 'Carlie']

# %%
tpl=(10,20)
print(tpl[0:2])
lst=list(tpl)
lst[0]=50
tpl=tuple(lst)
print(tpl)
# Out:
# (10, 20)
# (50, 20)

# %%
set={1,2,3,3,4}
print(set)
# Out:
# {1, 2, 3, 4}

# %%
set.add(5)
set.remove(2)
print(set)
# Out:
# {1, 3, 4, 5}

# %%
set1={1,2,3}
set2={3,4,5}
print(set1.union(set2))
print(set1.intersection(set2))
print(set1.difference(set2))
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

# %%
student={"name":"John","age":20,"grade":"A"}
print(student.get('name'))
student["grade"]='A+'
print(student)
student["city"]="Delhi"
print(student)
# Out:
# John
# {'name': 'John', 'age': 20, 'grade': 'A+'}
# {'name': 'John', 'age': 20, 'grade': 'A+', 'city': 'Delhi'}

# %%
contact={"Raunak":7000521346,"Shubham":7000521346,"Happy":8819051458}
print(contact.keys())
print(contact.values())
print(contact.items())
# Out:
# dict_keys(['Raunak', 'Shubham', 'Happy'])
# dict_values([7000521346, 7000521346, 8819051458])
# dict_items([('Raunak', 7000521346), ('Shubham', 7000521346), ('Happy', 8819051458)])

# %%
for keys in contact.keys():
    print(keys)

for values in contact.values():
    print(values)

for keys,values in contact.items():
    print (f"{keys}:{values}")
# Out:
# Raunak
# Shubham
# Happy
# 7000521346
# 7000521346
# 8819051458
# Raunak:7000521346
# Shubham:7000521346
# Happy:8819051458
