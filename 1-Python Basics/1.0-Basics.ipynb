# %%
# Basic Syntax Rules in Python
# Case Sensitivity - Python is case sensetive

name="Shubham"
Name="Ratan"

print(name)
print(Name)
# Out:
# Shubham
# Ratan

# %%
# Identation
# Python uses Identation to define bloacks of code

age=32
if age>=30:
    print("True")

print(age)
# Out:
# True
# 32

# %%
#Line Continuation
## Use a backlash (\) to continue a statement to the next line

total=1+2+3+4+5+6\
+7+8+9

print(total)
# Out:
# 45

# %%
# Multiple Statement in Single Line

x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
# Understanding semantics in Python
# Variable Assignement

age=29
name="Shubham"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
# Type Inference
variable=10
print(type(variable))
variable="Shubham"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=32
if age>30:
    print(age)
# Out:
# 32

# %%
## Code Example of Idenatation
if True:
    print("Correct Idenatation")
    if False:
        print("This one will not print")
    print("This will print")

print("Outside the if block")
# Out:
# Correct Idenatation
# This will print
# Outside the if block
