# %%
def convert_temperature(temp,unit):
    """This Function to convert temperature from celsius to Farenheit"""
    if unit=='C':
        return temp * (9/5) + 32 
    elif unit=='F':
        return (temp-32) * (5/9)
    else:
        return None

print(convert_temperature(25,'C'))
print(convert_temperature(77,'F'))
# Out:
# 77.0
# 25.0

# %%
def password_strength_check(password):
    """This Function checks if the password is strongo or weak"""
    if len(password)< 8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char in '!@#$%^&*()_+' for char in password):
        return False
    
    return True

## Calling the function

print(password_strength_check('Happy123'))
print(password_strength_check('Anittefaqq@10'))
# Out:
# False
# True

# %%
def calculate_total_cost(cart):
    """This function gives total cost of items is shopping cart"""
    total_cost=0
    for item in cart:
        total_cost+=item['price']*item['quantity']
    
    return total_cost

## example cart data

cart=[
{'name':'Apple','price':0.5,'quantity':4},
{'name':'Banana','price':0.3,'quantity':12},
{'name':'Orange','price':1.2,'quantity':6}

]

## Calling the function

total_cost=calculate_total_cost(cart)
print(total_cost)
# Out:
# 12.799999999999999

# %%
def pallindrome_check(word):
    """Function to check if a string is pallindrome or not"""
    word=word.lower().replace(" ","")
    return word==word[::-1]

print(pallindrome_check("A man a plan a canal panama"))
# Out:
# True

# %%
def factorial(n):
    """Function to find factorial of a number"""
    if n==0:
        return 1
    else:
        return n * factorial(n-1)
    

print(factorial(5))
print(factorial(1))
# Out:
# 120
# 1
