# %%
s='Shubham'
r="Ratan"
h='''Shubham Ratan is
a good boy'''

#  String Indexing
name="Happy"
print(name)
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[-1])
print(name[-2])
print(name[-3])
print(name[-4])
print(name[-5])
# Out:
# Happy
# H
# a
# p
# p
# y
# y
# p
# p
# a
# H

# %%
#String Slicing
name="Happy"
print(name[0:2])
print(name[2:-1])

#String Slicing with Step
print(name[0:5:1])
print(name[0:5:2])
print(name[:1])
print(name[1:])
# Out:
# Ha
# pp
# Happy
# Hpy
