# %%
#String Formatting

text ="Dear {}, You are awesome. Take this ${} bag"
a="John"
a1= 1000
b="Jcak"
b1=3000
c="Marry"
c1=5000
s1=text.format(b,b1) 
print(s1)
# Out:
# Dear Jcak, You are awesome. Take this $3000 bag

# %%
# F String
print(f"{a}, you are awesome. Take this {a1}$ bag.")
# Out:
# John, you are awesome. Take this 1000$ bag.

# %%
a=str(input("Enter any character"))
print(f"The ascii value is : {ord(a)}")
# Out:
# The ascii value is : 65

# %%
i=int(input("Enter any ascii number"))
print(f"The  character value is : {chr(i)}")
# Out:
# The  character value is : M

# %%
name = "Shubham"
age= 29
print("Hi my name is {} and I am {} years old.".format(name,age))
print(f"Hi my name is {name} and I am {age} years old.")
# Out:
# Hi my name is Shubham and I am 29 years old.
# Hi my name is Shubham and I am 29 years old.
