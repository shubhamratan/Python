# %%
#String Methods
name="Happy"  #Strings are immutable.

# name[0]="R" -- You cannot do this in python for strings

a = len(name)
print(a)
# Out:
# 5

# %%
s="hello world"
l=len(s)
print(l)
print(s.upper(),s)
print(s.lower())
print(s.capitalize())
print(s.title())
# Out:
# 11
# HELLO WORLD hello world
# hello world
# Hello world
# Hello World

# %%
s
print(s.strip())
print(s.lstrip())
print(s.rstrip())
# Out:
# hello world
# hello world
# hello world

# %%
#Find and Replace Methods

text ="Python is fun"
print(text.find("is"))
print(text.replace("fun","awesome"))
# Out:
# 7
# Python is awesome

# %%
# Split and Join Methods

fruits="apple,banana,guava"
fruits1=fruits.split(",")
print(fruits1)
print(",".join(['apple', 'banana', 'guava']))
# Out:
# ['apple', 'banana', 'guava']
# apple,banana,guava

# %%
text ="Python123"
print(text.isalpha())
print(text.isdigit()) 
print(text.isalnum()) 
print(text.isspace())
# Out:
# False
# False
# True
# False
