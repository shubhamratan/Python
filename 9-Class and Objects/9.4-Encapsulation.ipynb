# %%
# Encapsulation with Getter and Setter Methods
# Public, Protected, Private variable or access modifiers

class Person():
    def __init__(self,name,age):
        self.name=name #Public Variable
        self.age=age  #Public Variable


#Function outside the class

def get_name(Person):
    return Person.name
    
person=Person("Shubham",29)
print(person.name)
# Out:
# Shubham

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
get_name(person)
# Out:
# 'Shubham'

# %%
class Person():
    def __init__(self,name,age,gender):
        self.__name=name #Private Variable
        self.__age=age  #Private Variable
        self.gender=gender #Public Variable
  
def get_name(Person):
    return Person.__name

person=Person("Shubham",29,"Male")
get_name(person)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 11
#       8     return Person.__name
#      10 person=Person("Shubham",29,"Male")
# ---> 11 get_name(person)
#
# Cell In[17], line 8, in get_name(Person)
#       7 def get_name(Person):
# ----> 8     return Person.__name
#
# AttributeError: 'Person' object has no attribute '__name'

# %%
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
class Person():
    def __init__(self,name,age,gender):
        self._name=name #Protected Variable
        self._age=age  #Protected Variable
        self.gender=gender #Public Variable

class Employee(Person):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)


employee1=Employee("Shubham",29,"Male")
print(employee1._name)
# Out:
# Shubham

# %%
class Person():
    def __init__(self,name,age):
        self.__name=name #Private Variable
        self.__age=age  #Private Variable
    
    # Getter method for name
    def get_name(self):
        return self.__name
       
    # Setter method for name
    def set_name(self,name):
        self.__name=name

    # Getter method for age
    def get_age(self):
        return self.__age
    
    # Setter method for age
    def set_age(self,age):
        if age>0:
            self.__age=age
        else:
            print("Age cannot be negative")


person=Person("Shubham",29)

# Access and modify private variable using gettter and setter

print(person.get_name())
print(person.get_age())

person.set_age(35)
print(person.get_age())

person.set_name("Raunak")
print(person.get_name())
# Out:
# Shubham
# 29
# 35
# Raunak

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary

    def first_name(self):
        l=self.name.split(" ")
        return l[0]

    def set_first_name(self,first):
        l=self.name.split(" ")
        new_name=f"{first} {l[1]}"
        self.name=new_name

e1=Employee("Raunak Ratan", 35000)
print(e1.first_name())
e1.set_first_name("Shubham")
print(e1.name)
# Out:
# Raunak
# Shubham Ratan

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
    @property
    def first_name(self):
        l=self.name.split(" ")
        return l[0]
    @first_name.setter
    def first_name(self,first):
        l=self.name.split(" ")
        new_name=f"{first} {l[1]}"
        self.name=new_name

e1=Employee("Raunak Ratan", 35000)
print(e1.first_name)
e1.first_name="Shubham"
print(e1.name)
# Out:
# Raunak
# Shubham Ratan
