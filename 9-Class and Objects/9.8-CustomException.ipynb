# %%
class Error(Exception):
    pass

class DOBException(Error):
    pass

# %%
year=int(input("Enter the year of birth"))
age=2026-year

try:
    if age>=20 and age<=30:
        print("The age is valid and you can apply for the exam")
    else:
        raise DOBException
except DOBException:
    print("Did not met the age criterea to apply for the exam")
# Out:
# Did not met the age criterea to apply for the exam
