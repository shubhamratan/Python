# %%
# A class is the blueprint for creating objects. Attributes Methods

class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
print(type(audi))
# Out:
# <class '__main__.Car'>
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
audi.windows=4
print(audi.windows)
# Out:
# 4

# %%
tata=Car()
tata.door=4
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 tata=Car()
#       2 tata.door=4
# ----> 3 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'door']

# %%
# Instance Variable and Method

class Dog():
    # Constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
#create objects
dog1=Dog("Bruno",5)        
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Bruno
# 5

# %%
dog2=Dog("Lucy",5)
print(dog2)
print(dog2.name)
print(dog2.age)
# Out:
# ...
# Lucy
# 5

# %%
# Define a class with Instance methods

class Dog():
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def bark(self):
        print(f"{self.name} says woof!")
    
dog1=Dog("Buddy", 3)
dog1.bark()
dog2=Dog("Lucy", 5)
dog2.bark()
# Out:
# Buddy says woof!
# Lucy says woof!

# %%
## Modeling a bank account

class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
        print(f"A deposit of {amount} has been made in your account and updated balance is {self.balance}")
    def withdrawal(self,amount):
        if amount>self.balance:
            print("Insufficient Fund")
        else:
            self.balance-=amount
            print(f"A withdrawal of {amount} has been made from your account and updated balance is {self.balance}")
    def get_balance(self):
        print(f"Your account balance is {self.balance}")

# Create an account

account=BankAccount("Shubham",10000)
account.balance
# Out:
# 10000

# %%
# Call instance methods
account.get_balance()
account.deposit(1000)
account.withdrawal(5000)
# Out:
# Your account balance is 10000
# A deposit of 1000 has been made in your account and updated balance is 11000
# A withdrawal of 5000 has been made from your account and updated balance is 6000
