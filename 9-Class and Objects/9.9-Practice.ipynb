# %%
class Employee:
    company="Cognizant"

    def get_salary(self):
        return 35000

# %%
a=Employee()
a.get_salary()
# Out:
# 35000

# %%
class Employee:
    def __init__(self,name,salary,bond):
        self.name=name
        self.salary=salary
        self.bond=bond

    def get_salary(self):
        return self.salary
    
    def get_info(self):
        print (f"The name of the employee is {self.name}. Salary is {self.salary}. The bond is of {self.bond} years")

e1=Employee("Shubham",53000,2)
print(e1.get_salary())
e1.get_info()
# Out:
# 53000
# The name of the employee is Shubham. Salary is 53000. The bond is of 2 years

# %%
class Employee:
    company="Cognizant"

    def __init__(self,name,salary,bond,company):
        self.name=name
        self.salary=salary
        self.bond=bond
        self.company=company

    def get_salary(self):
        return self.salary
    
    def get_info(self):
        print (f"The name of the employee is {self.name}. He works in{self.company} Salary is {self.salary}. The bond is of {self.bond} years")

e1=Employee("Shubham",53000,2,"HP")
print(e1.get_salary())
e1.get_info()
# Out:
# 53000
# The name of the employee is Shubham. He works inHP Salary is 53000. The bond is of 2 years

# %%
e2=Employee("Raunak",35000,4,"Asus")
print(e2.get_salary())
e2.get_info()
print(Employee.company)
# Out:
# 35000
# The name of the employee is Raunak. He works inAsus Salary is 35000. The bond is of 4 years
# Cognizant

# %%
class Car:
    def drive(self):
        print("Car is moving")

car1=Car()
car1.drive()
# Out:
# Car is moving

# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
    def get_info(self):
        return f"{self.name} : {self.age}"
    

p1=Person("Shubham",29)
print(p1.get_info())
# Out:
# Shubham : 29

# %%
class Employee:
    def __init__(self,salary):
        self._salary=salary

    @property
    def salary(self):
        return self._salary
    
    @salary.setter
    def salary(self, new_salary):
        if new_salary<0:
            print("Salary cannot be negative")
        else:
            self._salary= new_salary
       
e=Employee(35000)
print(e.salary)
e.salary=50000
print(e.salary)
# Out:
# 35000
# 50000

# %%
class MathUtils:

    def __init__(self):
        pass

    @staticmethod
    def add(a,b):
        return a+b
    
    @classmethod
    def description(cls):
        return "This is a utility class for math operations"

print(MathUtils.add(3,5))
print(MathUtils.description())
# Out:
# 8
# This is a utility class for math operations

# %%
class Book:
    def __init__(self,title,author):
        self.title=title
        self.author=author

    def __str__(self):
        return (f"{self.title} by {self.author}")
    
    def __len__(self):
        return len(self.title)
    

b1 = Book("River Bed", "John Doe")
print(b1)
print(len(b1))

b2 = Book("Young India", "APJ Kalam")
print(b2)
print(len(b2))
# Out:
# River Bed by John Doe
# 9
# Young India by APJ Kalam
# 11
