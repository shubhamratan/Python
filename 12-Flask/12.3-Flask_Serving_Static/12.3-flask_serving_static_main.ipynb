# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route("/")
def hello_world():
    return render_template("index.html")

app.run(port=8000, debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8000
# Press CTRL+C to quit
# 127.0.0.1 - - [12/May/2026 18:19:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2026 18:19:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2026 18:19:13] "GET /static/1.mp4 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2026 18:19:13] "GET /static/1.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [12/May/2026 18:19:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2026 18:19:33] "GET /static/2.mp4 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2026 18:19:33] "GET /static/2.mp4 HTTP/1.1" 206 -
