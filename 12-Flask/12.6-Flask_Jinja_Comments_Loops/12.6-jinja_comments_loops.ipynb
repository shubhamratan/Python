# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route("/")
def hello_world():
    marks={
        "Shubham":98,
        "Raunak":75,
        "Rachit":80,
        "Ashank":95,
        "Naitik":85,
        "Siddhant":90,
        "Shlok":90,
        "Harry":1
    }
    return render_template("index.html", marks=marks)

app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [14/May/2026 11:48:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:48:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:50:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:50:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:50:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:52:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:52:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:52:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:52:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:52:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:53:06] "GET / HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\flask\app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\flask\app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\rauna\AppData\Local\Temp\ipykernel_20888\4164585309.py", line 17, in hello_world
#     return render_template("index.html", marks=marks)
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\flask\templating.py", line 149, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\jinja2\environment.py", line 1087, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\jinja2\environment.py", line 1016, in get_template
#     return self._load_template(name, globals)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\jinja2\environment.py", line 975, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\jinja2\loaders.py", line 138, in load
#     code = environment.compile(source, name, filename)
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\jinja2\environment.py", line 771, in compile
#     self.handle_exception(source=source_hint)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rauna\anaconda3\Lib\site-packages\jinja2\environment.py", line 942, in handle_exception
#     raise rewrite_traceback_stack(source=source)
#   File "d:\mylearning\python\12-Flask\12.6-Flask_Jinja_Comments_Loops\templates\index.html", line 12, in template
#     <li> The marks of {{key}} is {{marks.get(key). }}
#     ^^^^^^^^^^^^^^^
# jinja2.exceptions.TemplateSyntaxError: expected name or number
# 127.0.0.1 - - [14/May/2026 11:53:06] "GET /?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2026 11:53:06] "GET /?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2026 11:53:07] "GET /?__debugger__=yes&cmd=resource&f=console.png&s=DtDlzEovhC3uoKcTHmfC HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 11:53:07] "GET /?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2026 11:53:25] "GET / HTTP/1.1" 200 -
