# %%
#Conditional Statement

# Without walrus operator
data = input("Enter a value (or 'quit' to exit): ")

while data !="quit":
    print(f"You entered: {data}")
    data =input("Enter a value (or 'quit' to exit): ")

# %%
# With walrus operator
data = input("Enter a value (or 'quit' to exit): ")

while(data :=input("Enter a value (or 'quit' to exit): "))!="quit":
    print(f"You entered: {data}")
# Out:
# You entered: 11

# %%
# List Comprehension

numbers =[1,2,3,4,5]

# Without walrus operator:  calculate x * 2 twice

results =[x**2 for x in numbers if x**2>5]
print(results)
# Out:
# [9, 16, 25]

# %%
# With walrus operator: calculate x * 2 only once

results =[y for x in numbers if(y := x**2)>5]
print(results)
# Out:
# [9, 16, 25]

# %%
def very_slow_function():
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    return 7

if (very_slow_function()>10):
    print(very_slow_function())
else:
    print("It's not greater than 10")
# Out:
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# It's not greater than 10

# %%
def very_slow_function():
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    return 70

if (very_slow_function()>10):
    print(very_slow_function())
else:
    print("It's not greater than 10")
# Out:
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# 70

# %%
def very_slow_function():
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    return 70

a=very_slow_function()
if (a>10):
    print(a)
else:
    print("It's not greater than 10")
# Out:
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# 70

# %%
def very_slow_function():
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    print("Something.....")
    return 7

if ( (a:=very_slow_function()) >10):
    print(a)
else:
    print("It's not greater than 10")
# Out:
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# Something.....
# It's not greater than 10

# %%
# File Reading

# Without Walrus
with open("large_file.txt","r")as f:
    line = f.readline()
    while line:
        print(line.strip())
        line = f.readline()
# Out:
# Droupadi Murmu is the 15th and current President of India, having assumed office on July 25, 2022. As the head of state and supreme commander of the Indian Armed Forces, she is the first person from a tribal community and the youngest to hold the position. She succeeded Ram Nath Kovind.
# presidentofindia.gov.in
# presidentofindia.gov.in
# +3
# Key Details about President Droupadi Murmu:
# Term Began: July 25, 2022.
# Predecessor: Ram Nath Kovind.
# Background: Previously served as the Governor of Jharkhand (2015–2021).
# Role: The President is the nominal head of the executive and the first citizen of India.
# Residence: Rashtrapati Bhavan, New Delhi.
# Wikipedia
# Wikipedia
# +3
# Official information and updates regarding the President can be found on the official website and he

# %%
# With Walrus
with open("large_file.txt","r")as f:
    while(line := f.readline()):
        print(line.strip())
# Out:
# Droupadi Murmu is the 15th and current President of India, having assumed office on July 25, 2022. As the head of state and supreme commander of the Indian Armed Forces, she is the first person from a tribal community and the youngest to hold the position. She succeeded Ram Nath Kovind.
# presidentofindia.gov.in
# presidentofindia.gov.in
# +3
# Key Details about President Droupadi Murmu:
# Term Began: July 25, 2022.
# Predecessor: Ram Nath Kovind.
# Background: Previously served as the Governor of Jharkhand (2015–2021).
# Role: The President is the nominal head of the executive and the first citizen of India.
# Residence: Rashtrapati Bhavan, New Delhi.
# Wikipedia
# Wikipedia
# +3
# Official information and updates regarding the President can be found on the official website and he
