# %% [markdown]
# https://docs.python.org/3/py-modindex.html

# %%
import math
math.sqrt(4)

# %%
from math import sqrt,pi

print(sqrt(4))
print(pi)
print(sqrt(9))
# Out:
# 2.0
# 3.141592653589793
# 3.0

# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.4-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.4-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ------------- -------------------------- 4.2/12.3 MB 31.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.3 MB 28.2 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 22.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 20.9 MB/s  0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.4.4

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import*
print(sqrt(2))
print(pi)
# Out:
# 1.4142135623730951
# 3.141592653589793

# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package import maths
maths.addition(2,9)
# Out:
# 11

# %%
import moviepy

# %%
import requests

r = requests.get('https://api.github.com/users/codewithharry')

with open("Codewithharry.txt",'w') as file:
    file.write(r.text)

# %%
r = requests.post('https://httpbin.org/post', data={'key': 'value'})
