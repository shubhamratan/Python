# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(4))
print(math.pi)
# Out:
# 2.0
# 3.141592653589793

# %%
# Random

import random

print(random.randint(1,10))
print(random.choice(['apple','banana','cherry','guava']))
# Out:
# 8
# apple

# %%
# OS Library - File & Directory access

import os
print(os.getcwd())
os.mkdir('test_dir')
# Out:
# d:\python\6-Modules

# %%
# High Level operation on files and collection of files

import shutil
shutil.copy('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
# Data Serialization

import json
data={'name':'Shubham','age':30}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Shubham", "age": 30}
# <class 'str'>
# {'name': 'Shubham', 'age': 30}
# <class 'dict'>

# %%
# CSV

import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Shubham',29])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Shubham', '29']

# %%
#Datetime

from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-04-16 13:34:36.567095
# 2026-04-15 13:34:36.567095

# %%
# Time

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1776326751.3603258
# 1776326753.3619614

# %%
# Regular Expression

import re

pattern=r'\d+'
text='There are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
